# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# %matplotlib notebook

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
import json
from pprint import pprint


# Import API key
p = os.path.join("..","..","..","openWeather_api_key.txt")
f = open(p, "r")
api_key = f.read()
f.close()

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))

cities_df = pd.DataFrame({"cities": cities})
cities_df.head()
# Out:
# 606
#          cities
# 0  punta arenas
# 1       ushuaia
# 2       qaanaaq
# 3      hermanus
# 4        castro

# %%
#Verifying that the list of cities is unique if len(cities) = cities_df['cities'].value_counts().
print(f"{len(cities)} vs {len(cities_df['cities'].value_counts())}")
if len(cities) == len(cities_df['cities'].value_counts()):
    print("We already have a list of unique cities\n")
    print(cities_df['cities'].value_counts())
else:
    #overwriting cities list with unique values
    cities = cities_df['cities'].value_counts().tolist()
    print("Creating a list of unique cities from dataframe")
    pprint(cities)
# Out:
# 606 vs 606
# We already have a list of unique cities
#
# saint-joseph               1
# poli                       1
# lloydminster               1
# port macquarie             1
# busselton                  1
# kapaa                      1
# torit                      1
# uige                       1
# pacatuba                   1
# sangueya                   1
# carnarvon                  1
# japura                     1
# port blair                 1
# vysokogornyy               1
# hilo                       1
# osoyoos                    1
# grand gaube                1
# lima                       1
# leninskoye                 1
# te anau                    1
# nemuro                     1
# auki                       1
# severo-kurilsk             1
# atuona                     1
# ukiah                      1
# roald                      1
# namatanai                  1
# manokwari                  1
# kaspiyskiy                 1
# bull savanna               1
#                           ..
# boa vista                  1
# katsuura                   1
# dingle                     1
# beloha                     1
# sarakhs                    1
# san cristobal              1
# ceyhan                     1
# dallas                     1
# haibowan                   1
# radcliff                   1
# ilebo                      1
# houma                      1
# maputo                     1
# koslan                     1
# hervey bay                 1
# port elizabeth             1
# coihaique                  1
# villanueva de la serena    1
# san patricio               1
# nizhneyansk                1
# saint-agapit               1
# worcester                  1
# airai                      1
# rawson                     1
# new norfolk                1
# maksi                      1
# maimon                     1
# derzhavinsk                1
# kavieng                    1
# ayorou                     1
# Name: cities, Length: 606, dtype: int64

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print(f"Beginning Data Retrieval\n{'-'*30}")
#For make a request for each city
#Keeping track of failed cities' index
cities_fail = list()
try:
    for x in range(len(cities)):
        print(f"Processing Record {x} | {cities[x]}")
        # Build query URL and request your results in Celsius
        url = "http://api.openweathermap.org/data/2.5/forecast?"
        url = url +"APPID="+api_key+"&q="+cities[x]+"&units=metric"
        # Get weather data
        response = requests.get(url)

        #Checking to see if the call was a success
        if response.status_code == 200:
            
            #saving json in tmp folder as backup in case city call fails
            with open(f"tmp/{cities[x]}.json", 'w') as fp:
                json.dump(response.json(), fp)
        else:
            print("City not found. Skipping...")
            cities_fail.append({"name":cities[x], "index":x, "error":response.status_code})
    print(f"{'-'*30}\nData Retrieval Complete\n{'-'*30}")
except:
    print("something went wrong...")
    raise
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 0 | punta arenas
# Processing Record 1 | ushuaia
# Processing Record 2 | qaanaaq
# Processing Record 3 | hermanus
# Processing Record 4 | castro
# Processing Record 5 | aflu
# City not found. Skipping...
# Processing Record 6 | dingle
# Processing Record 7 | hamilton
# Processing Record 8 | kapaa
# Processing Record 9 | sao gabriel
# Processing Record 10 | walvis bay
# Processing Record 11 | margate
# Processing Record 12 | dikson
# Processing Record 13 | rikitea
# Processing Record 14 | puerto ayora
# Processing Record 15 | arraial do cabo
# Processing Record 16 | asyut
# Processing Record 17 | comodoro rivadavia
# Processing Record 18 | albany
# Processing Record 19 | manokwari
# Processing Record 20 | longyearbyen
# Processing Record 21 | neka
# Processing Record 22 | pisco
# Processing Record 23 | wote
# Processing Record 24 | maniitsoq
# Processing Record 25 | caravelas
# Processing Record 26 | naze
# Processing Record 27 | porirua
# Processing Record 28 | katsuura
# Processing Record 29 | ayorou
# Processing Record 30 | port elizabeth
# Processing Record 31 | muisne
# Processing Record 32 | saint-augustin
# Processing Record 33 | codrington
# Processing Record 34 | ancud
# Processing Record 35 | zhigansk
# Processing Record 36 | atuona
# Processing Record 37 | deputatskiy
# Processing Record 38 | vostok
# Processing Record 39 | belushya guba
# City not found. Skipping...
# Processing Record 40 | jamestown
# Processing Record 41 | bengkulu
# City not found. Skipping...
# Processing Record 42 | kouroussa
# Processing Record 43 | pevek
# Processing Record 44 | saskylakh
# Processing Record 45 | jiayuguan
# Processing Record 46 | hithadhoo
# Processing Record 47 | maputo
# Processing Record 48 | yellowknife
# Processing Record 49 | bend
# Processing Record 50 | terme
# Processing Record 51 | kerema
# Processing Record 52 | birao
# Processing Record 53 | toropets
# Processing Record 54 | japura
# Processing Record 55 | vallenar
# Processing Record 56 | tuktoyaktuk
# Processing Record 57 | mataura
# Processing Record 58 | osoyoos
# Processing Record 59 | betare oya
# Processing Record 60 | belmonte
# Processing Record 61 | hilo
# Processing Record 62 | bluff
# Processing Record 63 | thompson
# Processing Record 64 | barentsburg
# City not found. Skipping...
# Processing Record 65 | sokoni
# Processing Record 66 | lucea
# Processing Record 67 | busselton
# Processing Record 68 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 69 | tasiilaq
# Processing Record 70 | chokurdakh
# Processing Record 71 | richards bay
# Processing Record 72 | faanui
# Processing Record 73 | bambous virieux
# Processing Record 74 | worcester
# Processing Record 75 | te anau
# Processing Record 76 | voh
# Processing Record 77 | port alfred
# Processing Record 78 | vaini
# Processing Record 79 | cherskiy
# Processing Record 80 | oranjemund
# Processing Record 81 | souillac
# Processing Record 82 | cairns
# Processing Record 83 | nizhneyansk
# City not found. Skipping...
# Processing Record 84 | belyy yar
# Processing Record 85 | beringovskiy
# Processing Record 86 | tangermunde
# Processing Record 87 | bredasdorp
# Processing Record 88 | waipawa
# Processing Record 89 | nanortalik
# Processing Record 90 | butaritari
# Processing Record 91 | cape town
# Processing Record 92 | kaka
# Processing Record 93 | tabora
# Processing Record 94 | hami
# Processing Record 95 | nanakuli
# Processing Record 96 | radcliff
# Processing Record 97 | new norfolk
# Processing Record 98 | bethel
# Processing Record 99 | east london
# Processing Record 100 | auki
# Processing Record 101 | suntar
# Processing Record 102 | kaitangata
# Processing Record 103 | carnarvon
# Processing Record 104 | mount gambier
# Processing Record 105 | avarua
# Processing Record 106 | pitea
# Processing Record 107 | komsomolskiy
# Processing Record 108 | lebu
# Processing Record 109 | wulanhaote
# City not found. Skipping...
# Processing Record 110 | dakar
# Processing Record 111 | geraldton
# Processing Record 112 | polyarnyy
# Processing Record 113 | georgetown
# Processing Record 114 | hervey bay
# Processing Record 115 | hihifo
# City not found. Skipping...
# Processing Record 116 | tarakan
# Processing Record 117 | mocambique
# City not found. Skipping...
# Processing Record 118 | namatanai
# Processing Record 119 | san patricio
# Processing Record 120 | hobart
# Processing Record 121 | leninskoye
# Processing Record 122 | kintampo
# Processing Record 123 | port blair
# Processing Record 124 | karauzyak
# City not found. Skipping...
# Processing Record 125 | kajaani
# Processing Record 126 | zhanatas
# City not found. Skipping...
# Processing Record 127 | koungou
# City not found. Skipping...
# Processing Record 128 | tsihombe
# City not found. Skipping...
# Processing Record 129 | mys shmidta
# City not found. Skipping...
# Processing Record 130 | broken hill
# Processing Record 131 | saldanha
# Processing Record 132 | inuvik
# Processing Record 133 | barrow
# Processing Record 134 | uige
# Processing Record 135 | taolanaro
# City not found. Skipping...
# Processing Record 136 | bathsheba
# Processing Record 137 | sinnamary
# Processing Record 138 | hasaki
# Processing Record 139 | natchitoches
# Processing Record 140 | grindavik
# Processing Record 141 | matara
# Processing Record 142 | gizo
# Processing Record 143 | vysokogornyy
# Processing Record 144 | yumen
# Processing Record 145 | palmer
# Processing Record 146 | mehamn
# Processing Record 147 | maine-soroa
# Processing Record 148 | grand river south east
# City not found. Skipping...
# Processing Record 149 | khonuu
# City not found. Skipping...
# Processing Record 150 | katobu
# Processing Record 151 | yeppoon
# Processing Record 152 | belousovka
# Processing Record 153 | kiama
# Processing Record 154 | pangnirtung
# Processing Record 155 | geresk
# City not found. Skipping...
# Processing Record 156 | sol-iletsk
# Processing Record 157 | udachnyy
# Processing Record 158 | kodiak
# Processing Record 159 | onega
# Processing Record 160 | umba
# Processing Record 161 | bara
# Processing Record 162 | leningradskiy
# Processing Record 163 | torreon
# City not found. Skipping...
# Processing Record 164 | swan hill
# Processing Record 165 | byron bay
# Processing Record 166 | ribeira grande
# Processing Record 167 | tocopilla
# Processing Record 168 | alta floresta
# Processing Record 169 | luderitz
# Processing Record 170 | saint-joseph
# Processing Record 171 | alice springs
# Processing Record 172 | dubreka
# Processing Record 173 | mwingi
# Processing Record 174 | hirara
# Processing Record 175 | ostuman
# City not found. Skipping...
# Processing Record 176 | kruisfontein
# Processing Record 177 | sitka
# Processing Record 178 | batagay
# Processing Record 179 | ljungby
# Processing Record 180 | belaya gora
# Processing Record 181 | kavaratti
# Processing Record 182 | ust-nera
# Processing Record 183 | rawson
# Processing Record 184 | diglur
# Processing Record 185 | nikolskoye
# Processing Record 186 | ponta do sol
# Processing Record 187 | udaipura
# Processing Record 188 | nemuro
# Processing Record 189 | sataua
# City not found. Skipping...
# Processing Record 190 | phuket
# Processing Record 191 | bredy
# Processing Record 192 | valley city
# Processing Record 193 | kimbe
# Processing Record 194 | cabo san lucas
# Processing Record 195 | taybad
# Processing Record 196 | tumannyy
# City not found. Skipping...
# Processing Record 197 | sao filipe
# Processing Record 198 | astoria
# Processing Record 199 | mezen
# Processing Record 200 | ocos
# Processing Record 201 | yatou
# Processing Record 202 | praya
# Processing Record 203 | svetlyy
# City not found. Skipping...
# Processing Record 204 | riyadh
# Processing Record 205 | karaul
# City not found. Skipping...
# Processing Record 206 | kegayli
# City not found. Skipping...
# Processing Record 207 | berlevag
# Processing Record 208 | mahebourg
# Processing Record 209 | saint-philippe
# Processing Record 210 | torit
# City not found. Skipping...
# Processing Record 211 | assiniboia
# Processing Record 212 | melville
# Processing Record 213 | attawapiskat
# City not found. Skipping...
# Processing Record 214 | seydi
# Processing Record 215 | broome
# Processing Record 216 | aklavik
# Processing Record 217 | maksi
# Processing Record 218 | muros
# Processing Record 219 | pokhara
# Processing Record 220 | danciulesti
# Processing Record 221 | lompoc
# Processing Record 222 | barra patuca
# Processing Record 223 | luanda
# Processing Record 224 | vaitupu
# City not found. Skipping...
# Processing Record 225 | kamyshin
# Processing Record 226 | abaete
# Processing Record 227 | turukhansk
# Processing Record 228 | bismarck
# Processing Record 229 | charlottesville
# Processing Record 230 | batuan
# Processing Record 231 | korla
# City not found. Skipping...
# Processing Record 232 | mar del plata
# Processing Record 233 | aykhal
# Processing Record 234 | puerto carreno
# Processing Record 235 | khatanga
# Processing Record 236 | kalabo
# Processing Record 237 | praia da vitoria
# Processing Record 238 | yar-sale
# Processing Record 239 | jalu
# Processing Record 240 | chuy
# Processing Record 241 | chengde
# Processing Record 242 | artyk
# City not found. Skipping...
# Processing Record 243 | sangueya
# Processing Record 244 | koslan
# Processing Record 245 | baiao
# Processing Record 246 | san policarpo
# Processing Record 247 | salalah
# Processing Record 248 | san quintin
# Processing Record 249 | avera
# Processing Record 250 | shediac
# Processing Record 251 | airai
# Processing Record 252 | bandarbeyla
# Processing Record 253 | emba
# Processing Record 254 | fortuna
# Processing Record 255 | korfovskiy
# Processing Record 256 | urumqi
# City not found. Skipping...
# Processing Record 257 | husavik
# Processing Record 258 | umzimvubu
# City not found. Skipping...
# Processing Record 259 | quzhou
# Processing Record 260 | hailey
# Processing Record 261 | kahului
# Processing Record 262 | robinson
# Processing Record 263 | baykit
# Processing Record 264 | olafsvik
# City not found. Skipping...
# Processing Record 265 | santa cruz del sur
# Processing Record 266 | kavieng
# Processing Record 267 | esperance
# Processing Record 268 | vaitape
# Processing Record 269 | lloydminster
# Processing Record 270 | oktyabrskoye
# Processing Record 271 | angoche
# Processing Record 272 | srednekolymsk
# Processing Record 273 | ilebo
# Processing Record 274 | luang prabang
# Processing Record 275 | torbay
# Processing Record 276 | sortland
# Processing Record 277 | borama
# City not found. Skipping...
# Processing Record 278 | polewali
# Processing Record 279 | samusu
# City not found. Skipping...
# Processing Record 280 | vardo
# Processing Record 281 | grand gaube
# Processing Record 282 | crab hill
# City not found. Skipping...
# Processing Record 283 | salinopolis
# Processing Record 284 | kralendijk
# Processing Record 285 | sao felix do xingu
# Processing Record 286 | korhogo
# Processing Record 287 | gushikawa
# Processing Record 288 | uglekamensk
# Processing Record 289 | beyneu
# Processing Record 290 | tual
# Processing Record 291 | soyo
# Processing Record 292 | kucevo
# Processing Record 293 | palabuhanratu
# City not found. Skipping...
# Processing Record 294 | tomohon
# Processing Record 295 | xuddur
# Processing Record 296 | guerrero negro
# Processing Record 297 | devils lake
# Processing Record 298 | bonoua
# Processing Record 299 | severo-kurilsk
# Processing Record 300 | sistranda
# Processing Record 301 | awbari
# Processing Record 302 | jos
# Processing Record 303 | varkaus
# Processing Record 304 | zhezkazgan
# Processing Record 305 | klyuchi
# Processing Record 306 | lambarene
# Processing Record 307 | cheuskiny
# City not found. Skipping...
# Processing Record 308 | gweta
# Processing Record 309 | saint-pierre
# Processing Record 310 | huarmey
# Processing Record 311 | midland
# Processing Record 312 | maceio
# Processing Record 313 | kaspiyskiy
# Processing Record 314 | sola
# Processing Record 315 | huazolotitlan
# City not found. Skipping...
# Processing Record 316 | kakching
# Processing Record 317 | kampot
# Processing Record 318 | amderma
# City not found. Skipping...
# Processing Record 319 | abu dhabi
# Processing Record 320 | yabelo
# Processing Record 321 | porto novo
# Processing Record 322 | ukiah
# Processing Record 323 | alihe
# Processing Record 324 | gamba
# Processing Record 325 | lagoa
# Processing Record 326 | san nicolas
# Processing Record 327 | tiksi
# Processing Record 328 | padang
# Processing Record 329 | saint george
# Processing Record 330 | the valley
# Processing Record 331 | dobresti
# Processing Record 332 | tuatapere
# Processing Record 333 | los llanos de aridane
# Processing Record 334 | ulagan
# Processing Record 335 | rungata
# City not found. Skipping...
# Processing Record 336 | eldikan
# City not found. Skipping...
# Processing Record 337 | marcona
# City not found. Skipping...
# Processing Record 338 | sur
# Processing Record 339 | asau
# City not found. Skipping...
# Processing Record 340 | buraydah
# Processing Record 341 | eucaliptus
# Processing Record 342 | iqaluit
# Processing Record 343 | malwan
# City not found. Skipping...
# Processing Record 344 | mitu
# Processing Record 345 | bilma
# Processing Record 346 | san carlos del zulia
# Processing Record 347 | norman wells
# Processing Record 348 | aquiraz
# Processing Record 349 | victoria
# Processing Record 350 | qandahar
# City not found. Skipping...
# Processing Record 351 | adrar
# Processing Record 352 | hidrolandia
# Processing Record 353 | boa vista
# Processing Record 354 | collingwood
# Processing Record 355 | bull savanna
# Processing Record 356 | sarakhs
# Processing Record 357 | acapulco
# Processing Record 358 | nara
# Processing Record 359 | mahon
# Processing Record 360 | ceyhan
# Processing Record 361 | fomboni
# Processing Record 362 | constitucion
# Processing Record 363 | lashio
# Processing Record 364 | salamanca
# Processing Record 365 | suoyarvi
# Processing Record 366 | saleaula
# City not found. Skipping...
# Processing Record 367 | patnos
# Processing Record 368 | cidreira
# Processing Record 369 | evensk
# Processing Record 370 | saint-georges
# Processing Record 371 | ambilobe
# Processing Record 372 | moyobamba
# Processing Record 373 | vagamo
# Processing Record 374 | kokkola
# Processing Record 375 | lorengau
# Processing Record 376 | lata
# Processing Record 377 | shenjiamen
# Processing Record 378 | filingue
# Processing Record 379 | mayo
# Processing Record 380 | waingapu
# Processing Record 381 | ketchikan
# Processing Record 382 | havre-saint-pierre
# Processing Record 383 | yakovlevka
# Processing Record 384 | guane
# Processing Record 385 | beloha
# Processing Record 386 | manta
# Processing Record 387 | zakamensk
# Processing Record 388 | guijalo
# Processing Record 389 | haibowan
# City not found. Skipping...
# Processing Record 390 | jeremie
# Processing Record 391 | derzhavinsk
# Processing Record 392 | shingu
# Processing Record 393 | mogadishu
# Processing Record 394 | camacha
# Processing Record 395 | coquimbo
# Processing Record 396 | haldensleben
# Processing Record 397 | karaton
# Processing Record 398 | rudnichnyy
# Processing Record 399 | pizarro
# Processing Record 400 | samarai
# Processing Record 401 | upernavik
# Processing Record 402 | lavrentiya
# Processing Record 403 | sabalgarh
# Processing Record 404 | san vicente
# Processing Record 405 | santo tomas
# Processing Record 406 | talnakh
# Processing Record 407 | san cristobal
# Processing Record 408 | namibe
# Processing Record 409 | uzhur
# Processing Record 410 | biograd na moru
# Processing Record 411 | bako
# Processing Record 412 | dapaong
# Processing Record 413 | orikhove
# Processing Record 414 | wahran
# City not found. Skipping...
# Processing Record 415 | presidencia roque saenz pena
# Processing Record 416 | kununurra
# Processing Record 417 | davidson
# Processing Record 418 | koutiala
# Processing Record 419 | mende
# Processing Record 420 | makanya
# Processing Record 421 | chapais
# Processing Record 422 | houma
# Processing Record 423 | atar
# Processing Record 424 | kirakira
# Processing Record 425 | puente de ixtla
# Processing Record 426 | plotnikovo
# Processing Record 427 | pirovskoye
# Processing Record 428 | paamiut
# Processing Record 429 | karratha
# Processing Record 430 | poli
# Processing Record 431 | saint-leu
# Processing Record 432 | makakilo city
# Processing Record 433 | opuwo
# Processing Record 434 | bairiki
# City not found. Skipping...
# Processing Record 435 | kenai
# Processing Record 436 | russell
# Processing Record 437 | half moon bay
# Processing Record 438 | mulege
# Processing Record 439 | tura
# Processing Record 440 | kaspiysk
# Processing Record 441 | sorland
# Processing Record 442 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 443 | poltavka
# Processing Record 444 | carndonagh
# Processing Record 445 | vieques
# Processing Record 446 | chagda
# City not found. Skipping...
# Processing Record 447 | yuanping
# Processing Record 448 | szigetvar
# Processing Record 449 | coihaique
# Processing Record 450 | tommot
# Processing Record 451 | ixtapa
# Processing Record 452 | eureka
# Processing Record 453 | karasjok
# Processing Record 454 | macaboboni
# City not found. Skipping...
# Processing Record 455 | port lincoln
# Processing Record 456 | mezhova
# Processing Record 457 | yulara
# Processing Record 458 | codajas
# Processing Record 459 | ilulissat
# Processing Record 460 | ambunti
# Processing Record 461 | tasbuget
# City not found. Skipping...
# Processing Record 462 | maridi
# City not found. Skipping...
# Processing Record 463 | naftah
# City not found. Skipping...
# Processing Record 464 | sentyabrskiy
# City not found. Skipping...
# Processing Record 465 | araouane
# Processing Record 466 | santiago del estero
# Processing Record 467 | chute-aux-outardes
# Processing Record 468 | healdsburg
# Processing Record 469 | aksarka
# Processing Record 470 | lewistown
# Processing Record 471 | provideniya
# Processing Record 472 | alfonsine
# Processing Record 473 | nelson bay
# Processing Record 474 | kondinskoye
# Processing Record 475 | paita
# Processing Record 476 | stoyba
# City not found. Skipping...
# Processing Record 477 | sawakin
# Processing Record 478 | monroe
# Processing Record 479 | ust-tsilma
# Processing Record 480 | sitrah
# Processing Record 481 | mamallapuram
# Processing Record 482 | clarence town
# Processing Record 483 | port hedland
# Processing Record 484 | xiaoweizhai
# Processing Record 485 | maghama
# City not found. Skipping...
# Processing Record 486 | grand-santi
# Processing Record 487 | sao sepe
# Processing Record 488 | bonavista
# Processing Record 489 | skalistyy
# City not found. Skipping...
# Processing Record 490 | meulaboh
# Processing Record 491 | minab
# Processing Record 492 | kiruna
# Processing Record 493 | biak
# Processing Record 494 | lingao
# Processing Record 495 | boddam
# Processing Record 496 | osakarovka
# Processing Record 497 | altay
# Processing Record 498 | cockburn town
# Processing Record 499 | lima
# Processing Record 500 | mortka
# Processing Record 501 | camaguey
# Processing Record 502 | hirado
# Processing Record 503 | banda aceh
# Processing Record 504 | thinadhoo
# Processing Record 505 | vila velha
# Processing Record 506 | touros
# Processing Record 507 | petropavlovsk-kamchatskiy
# Processing Record 508 | kwinana
# Processing Record 509 | calabozo
# Processing Record 510 | chino valley
# Processing Record 511 | taltal
# Processing Record 512 | egvekinot
# Processing Record 513 | along
# Processing Record 514 | tulun
# Processing Record 515 | ostrovnoy
# Processing Record 516 | dallas
# Processing Record 517 | matay
# Processing Record 518 | marshfield
# Processing Record 519 | quatre cocos
# Processing Record 520 | barbar
# City not found. Skipping...
# Processing Record 521 | abu samrah
# Processing Record 522 | ilhabela
# Processing Record 523 | hsinchu
# Processing Record 524 | ballina
# Processing Record 525 | ahipara
# Processing Record 526 | saint-agapit
# Processing Record 527 | kuching
# Processing Record 528 | port macquarie
# Processing Record 529 | itarema
# Processing Record 530 | kamenskoye
# City not found. Skipping...
# Processing Record 531 | yayva
# Processing Record 532 | okandja
# City not found. Skipping...
# Processing Record 533 | toora-khem
# Processing Record 534 | pamanukan
# Processing Record 535 | serpa
# Processing Record 536 | middelburg
# Processing Record 537 | berga
# Processing Record 538 | okhotsk
# Processing Record 539 | kearney
# Processing Record 540 | fengcheng
# Processing Record 541 | orikhiv
# Processing Record 542 | dogondoutchi
# Processing Record 543 | tselinnoye
# Processing Record 544 | mayumba
# Processing Record 545 | hualmay
# Processing Record 546 | funtua
# Processing Record 547 | isangel
# Processing Record 548 | narrabri
# Processing Record 549 | brisbane
# Processing Record 550 | sabha
# Processing Record 551 | honningsvag
# Processing Record 552 | villanueva de la serena
# Processing Record 553 | dajabon
# Processing Record 554 | sakakah
# City not found. Skipping...
# Processing Record 555 | panguna
# Processing Record 556 | trairi
# Processing Record 557 | zhob
# Processing Record 558 | santa marta
# Processing Record 559 | balimo
# City not found. Skipping...
# Processing Record 560 | pergamino
# Processing Record 561 | laredo
# Processing Record 562 | tevaitoa
# Processing Record 563 | fort nelson
# Processing Record 564 | mazamari
# Processing Record 565 | sergeyevka
# Processing Record 566 | del rio
# Processing Record 567 | huilong
# Processing Record 568 | kieta
# Processing Record 569 | pimentel
# Processing Record 570 | bambanglipuro
# Processing Record 571 | eston
# Processing Record 572 | roald
# Processing Record 573 | mergui
# City not found. Skipping...
# Processing Record 574 | yerbogachen
# Processing Record 575 | maimon
# City not found. Skipping...
# Processing Record 576 | bowling green
# Processing Record 577 | kaeo
# Processing Record 578 | athens
# Processing Record 579 | longlac
# City not found. Skipping...
# Processing Record 580 | warangal
# Processing Record 581 | gusinoye ozero
# Processing Record 582 | mount isa
# Processing Record 583 | jalingo
# Processing Record 584 | pacatuba
# Processing Record 585 | villazon
# City not found. Skipping...
# Processing Record 586 | qasigiannguit
# Processing Record 587 | ozgon
# City not found. Skipping...
# Processing Record 588 | laguna
# Processing Record 589 | mandali
# Processing Record 590 | sorvag
# City not found. Skipping...
# Processing Record 591 | turkistan
# City not found. Skipping...
# Processing Record 592 | zhicheng
# Processing Record 593 | haimen
# Processing Record 594 | sesheke
# Processing Record 595 | fuyang
# Processing Record 596 | baruun-urt
# Processing Record 597 | monrovia
# Processing Record 598 | san felipe
# Processing Record 599 | churapcha
# Processing Record 600 | igrim
# Processing Record 601 | gat
# Processing Record 602 | christchurch
# Processing Record 603 | bojnurd
# Processing Record 604 | grand baie
# Processing Record 605 | makushino
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
#Getting the Data that was retrieved

list_jsons = os.listdir('tmp')
len(list_jsons)
# Out:
# 534

# %%
#City	Cloudiness	Country	Date	Humidity	Lat	Lng	Max Temp	Wind Speed
CityName = list()
Cloudiness = list()
CountryCode = list()
Date = list()
Humidity = list()
Lat = list()
Lng = list()
MaxTemp = list()
WindSpeed = list()

#for file in list_jsons:
for x in range(len(list_jsons)):
    try:
        print(f"loading and parsing data for {list_jsons[x]} | {x+1} of {len(list_jsons)}")
        with open(f"tmp/{list_jsons[x]}") as jsonfile:
            cityDict = json.load(jsonfile)
            
            #Getting data from json, in case of error
            name = cityDict['city']['name']
            cloud = cityDict['list'][0]['clouds']['all']
            cCode = cityDict['city']['country']
            fecha = cityDict['list'][0]['dt']
            Humid = cityDict['list'][0]['main']['humidity']
            Latit = cityDict['city']['coord']['lat']
            Longi = cityDict['city']['coord']['lon']
            temp = cityDict['list'][0]['main']['temp_max']
            speed = cityDict['list'][0]['wind']['speed']
            
            #Saving Data for each city that worked (No errors/exceptions were raised)
            CityName.append(name)
            Cloudiness.append(cloud)
            CountryCode.append(cCode)
            Date.append(fecha)
            Humidity.append(Humid)
            Lat.append(Latit)
            Lng.append(Longi)
            MaxTemp.append(temp)
            WindSpeed.append(speed)

    except IOError:
        print(f"Error with {list_jsons[x]}")
        raise
    except:
        print("Something went wrong...")
        raise
print(f"\n{'-'*30}\nFinished Loading, Parsing and extracting Data\n{'-'*30}")

if(len(CityName) == len(list_jsons)):
    print(f"No errors found, task finished successfully\n{'-'*30}")
else:
    print(f"There were {len(list_jsons)-len(CityName)} errors!!!\n{'-'*30}")
# Out:
# loading and parsing data for abaete.json | 1 of 534
# loading and parsing data for abu dhabi.json | 2 of 534
# loading and parsing data for abu samrah.json | 3 of 534
# loading and parsing data for acapulco.json | 4 of 534
# loading and parsing data for adrar.json | 5 of 534
# loading and parsing data for ahipara.json | 6 of 534
# loading and parsing data for airai.json | 7 of 534
# loading and parsing data for aklavik.json | 8 of 534
# loading and parsing data for aksarka.json | 9 of 534
# loading and parsing data for albany.json | 10 of 534
# loading and parsing data for alfonsine.json | 11 of 534
# loading and parsing data for alice springs.json | 12 of 534
# loading and parsing data for alihe.json | 13 of 534
# loading and parsing data for along.json | 14 of 534
# loading and parsing data for alta floresta.json | 15 of 534
# loading and parsing data for altay.json | 16 of 534
# loading and parsing data for ambilobe.json | 17 of 534
# loading and parsing data for ambunti.json | 18 of 534
# loading and parsing data for ancud.json | 19 of 534
# loading and parsing data for angoche.json | 20 of 534
# loading and parsing data for aquiraz.json | 21 of 534
# loading and parsing data for araouane.json | 22 of 534
# loading and parsing data for arraial do cabo.json | 23 of 534
# loading and parsing data for assiniboia.json | 24 of 534
# loading and parsing data for astoria.json | 25 of 534
# loading and parsing data for asyut.json | 26 of 534
# loading and parsing data for atar.json | 27 of 534
# loading and parsing data for athens.json | 28 of 534
# loading and parsing data for atuona.json | 29 of 534
# loading and parsing data for auki.json | 30 of 534
# loading and parsing data for avarua.json | 31 of 534
# loading and parsing data for avera.json | 32 of 534
# loading and parsing data for awbari.json | 33 of 534
# loading and parsing data for aykhal.json | 34 of 534
# loading and parsing data for ayorou.json | 35 of 534
# loading and parsing data for baiao.json | 36 of 534
# loading and parsing data for bako.json | 37 of 534
# loading and parsing data for ballina.json | 38 of 534
# loading and parsing data for bambanglipuro.json | 39 of 534
# loading and parsing data for bambous virieux.json | 40 of 534
# loading and parsing data for banda aceh.json | 41 of 534
# loading and parsing data for bandarbeyla.json | 42 of 534
# loading and parsing data for bara.json | 43 of 534
# loading and parsing data for barra patuca.json | 44 of 534
# loading and parsing data for barrow.json | 45 of 534
# loading and parsing data for baruun-urt.json | 46 of 534
# loading and parsing data for batagay.json | 47 of 534
# loading and parsing data for bathsheba.json | 48 of 534
# loading and parsing data for batuan.json | 49 of 534
# loading and parsing data for baykit.json | 50 of 534
# loading and parsing data for belaya gora.json | 51 of 534
# loading and parsing data for belmonte.json | 52 of 534
# loading and parsing data for beloha.json | 53 of 534
# loading and parsing data for belousovka.json | 54 of 534
# loading and parsing data for belyy yar.json | 55 of 534
# loading and parsing data for bend.json | 56 of 534
# loading and parsing data for berga.json | 57 of 534
# loading and parsing data for beringovskiy.json | 58 of 534
# loading and parsing data for berlevag.json | 59 of 534
# loading and parsing data for betare oya.json | 60 of 534
# loading and parsing data for bethel.json | 61 of 534
# loading and parsing data for beyneu.json | 62 of 534
# loading and parsing data for biak.json | 63 of 534
# loading and parsing data for bilma.json | 64 of 534
# loading and parsing data for biograd na moru.json | 65 of 534
# loading and parsing data for birao.json | 66 of 534
# loading and parsing data for bismarck.json | 67 of 534
# loading and parsing data for bluff.json | 68 of 534
# loading and parsing data for boa vista.json | 69 of 534
# loading and parsing data for boddam.json | 70 of 534
# loading and parsing data for bojnurd.json | 71 of 534
# loading and parsing data for bonavista.json | 72 of 534
# loading and parsing data for bonoua.json | 73 of 534
# loading and parsing data for bowling green.json | 74 of 534
# loading and parsing data for bredasdorp.json | 75 of 534
# loading and parsing data for bredy.json | 76 of 534
# loading and parsing data for brisbane.json | 77 of 534
# loading and parsing data for broken hill.json | 78 of 534
# loading and parsing data for broome.json | 79 of 534
# loading and parsing data for bull savanna.json | 80 of 534
# loading and parsing data for buraydah.json | 81 of 534
# loading and parsing data for busselton.json | 82 of 534
# loading and parsing data for butaritari.json | 83 of 534
# loading and parsing data for byron bay.json | 84 of 534
# loading and parsing data for cabo san lucas.json | 85 of 534
# loading and parsing data for cairns.json | 86 of 534
# loading and parsing data for calabozo.json | 87 of 534
# loading and parsing data for camacha.json | 88 of 534
# loading and parsing data for camaguey.json | 89 of 534
# loading and parsing data for cape town.json | 90 of 534
# loading and parsing data for caravelas.json | 91 of 534
# loading and parsing data for carnarvon.json | 92 of 534
# loading and parsing data for carndonagh.json | 93 of 534
# loading and parsing data for castro.json | 94 of 534
# loading and parsing data for ceyhan.json | 95 of 534
# loading and parsing data for chapais.json | 96 of 534
# loading and parsing data for charlottesville.json | 97 of 534
# loading and parsing data for chengde.json | 98 of 534
# loading and parsing data for cherskiy.json | 99 of 534
# loading and parsing data for chino valley.json | 100 of 534
# loading and parsing data for chokurdakh.json | 101 of 534
# loading and parsing data for christchurch.json | 102 of 534
# loading and parsing data for churapcha.json | 103 of 534
# loading and parsing data for chute-aux-outardes.json | 104 of 534
# loading and parsing data for chuy.json | 105 of 534
# loading and parsing data for cidreira.json | 106 of 534
# loading and parsing data for clarence town.json | 107 of 534
# loading and parsing data for cockburn town.json | 108 of 534
# loading and parsing data for codajas.json | 109 of 534
# loading and parsing data for codrington.json | 110 of 534
# loading and parsing data for coihaique.json | 111 of 534
# loading and parsing data for collingwood.json | 112 of 534
# loading and parsing data for comodoro rivadavia.json | 113 of 534
# loading and parsing data for constitucion.json | 114 of 534
# loading and parsing data for coquimbo.json | 115 of 534
# loading and parsing data for dajabon.json | 116 of 534
# loading and parsing data for dakar.json | 117 of 534
# loading and parsing data for dallas.json | 118 of 534
# loading and parsing data for danciulesti.json | 119 of 534
# loading and parsing data for dapaong.json | 120 of 534
# loading and parsing data for davidson.json | 121 of 534
# loading and parsing data for del rio.json | 122 of 534
# loading and parsing data for deputatskiy.json | 123 of 534
# loading and parsing data for derzhavinsk.json | 124 of 534
# loading and parsing data for devils lake.json | 125 of 534
# loading and parsing data for diglur.json | 126 of 534
# loading and parsing data for dikson.json | 127 of 534
# loading and parsing data for dingle.json | 128 of 534
# loading and parsing data for dobresti.json | 129 of 534
# loading and parsing data for dogondoutchi.json | 130 of 534
# loading and parsing data for dubreka.json | 131 of 534
# loading and parsing data for east london.json | 132 of 534
# loading and parsing data for egvekinot.json | 133 of 534
# loading and parsing data for emba.json | 134 of 534
# loading and parsing data for esperance.json | 135 of 534
# loading and parsing data for eston.json | 136 of 534
# loading and parsing data for eucaliptus.json | 137 of 534
# loading and parsing data for eureka.json | 138 of 534
# loading and parsing data for evensk.json | 139 of 534
# loading and parsing data for faanui.json | 140 of 534
# loading and parsing data for fengcheng.json | 141 of 534
# loading and parsing data for filingue.json | 142 of 534
# loading and parsing data for fomboni.json | 143 of 534
# loading and parsing data for fort nelson.json | 144 of 534
# loading and parsing data for fortuna.json | 145 of 534
# loading and parsing data for funtua.json | 146 of 534
# loading and parsing data for fuyang.json | 147 of 534
# loading and parsing data for gamba.json | 148 of 534
# loading and parsing data for gat.json | 149 of 534
# loading and parsing data for georgetown.json | 150 of 534
# loading and parsing data for geraldton.json | 151 of 534
# loading and parsing data for gizo.json | 152 of 534
# loading and parsing data for grand baie.json | 153 of 534
# loading and parsing data for grand gaube.json | 154 of 534
# loading and parsing data for grand-santi.json | 155 of 534
# loading and parsing data for grindavik.json | 156 of 534
# loading and parsing data for guane.json | 157 of 534
# loading and parsing data for guerrero negro.json | 158 of 534
# loading and parsing data for guijalo.json | 159 of 534
# loading and parsing data for gushikawa.json | 160 of 534
# loading and parsing data for gusinoye ozero.json | 161 of 534
# loading and parsing data for gweta.json | 162 of 534
# loading and parsing data for hailey.json | 163 of 534
# loading and parsing data for haimen.json | 164 of 534
# loading and parsing data for haldensleben.json | 165 of 534
# loading and parsing data for half moon bay.json | 166 of 534
# loading and parsing data for hami.json | 167 of 534
# loading and parsing data for hamilton.json | 168 of 534
# loading and parsing data for hasaki.json | 169 of 534
# loading and parsing data for havre-saint-pierre.json | 170 of 534
# loading and parsing data for healdsburg.json | 171 of 534
# loading and parsing data for hermanus.json | 172 of 534
# loading and parsing data for hervey bay.json | 173 of 534
# loading and parsing data for hidrolandia.json | 174 of 534
# loading and parsing data for hilo.json | 175 of 534
# loading and parsing data for hirado.json | 176 of 534
# loading and parsing data for hirara.json | 177 of 534
# loading and parsing data for hithadhoo.json | 178 of 534
# loading and parsing data for hobart.json | 179 of 534
# loading and parsing data for honningsvag.json | 180 of 534
# loading and parsing data for houma.json | 181 of 534
# loading and parsing data for hsinchu.json | 182 of 534
# loading and parsing data for hualmay.json | 183 of 534
# loading and parsing data for huarmey.json | 184 of 534
# loading and parsing data for huilong.json | 185 of 534
# loading and parsing data for husavik.json | 186 of 534
# loading and parsing data for igrim.json | 187 of 534
# loading and parsing data for ilebo.json | 188 of 534
# loading and parsing data for ilhabela.json | 189 of 534
# loading and parsing data for ilulissat.json | 190 of 534
# loading and parsing data for inuvik.json | 191 of 534
# loading and parsing data for iqaluit.json | 192 of 534
# loading and parsing data for isangel.json | 193 of 534
# loading and parsing data for itarema.json | 194 of 534
# loading and parsing data for ixtapa.json | 195 of 534
# loading and parsing data for jalingo.json | 196 of 534
# loading and parsing data for jalu.json | 197 of 534
# loading and parsing data for jamestown.json | 198 of 534
# loading and parsing data for japura.json | 199 of 534
# loading and parsing data for jeremie.json | 200 of 534
# loading and parsing data for jiayuguan.json | 201 of 534
# loading and parsing data for jos.json | 202 of 534
# loading and parsing data for kaeo.json | 203 of 534
# loading and parsing data for kahului.json | 204 of 534
# loading and parsing data for kaitangata.json | 205 of 534
# loading and parsing data for kajaani.json | 206 of 534
# loading and parsing data for kaka.json | 207 of 534
# loading and parsing data for kakching.json | 208 of 534
# loading and parsing data for kalabo.json | 209 of 534
# loading and parsing data for kampot.json | 210 of 534
# loading and parsing data for kamyshin.json | 211 of 534
# loading and parsing data for kapaa.json | 212 of 534
# loading and parsing data for karasjok.json | 213 of 534
# loading and parsing data for karaton.json | 214 of 534
# loading and parsing data for karratha.json | 215 of 534
# loading and parsing data for kaspiysk.json | 216 of 534
# loading and parsing data for kaspiyskiy.json | 217 of 534
# loading and parsing data for katobu.json | 218 of 534
# loading and parsing data for katsuura.json | 219 of 534
# loading and parsing data for kavaratti.json | 220 of 534
# loading and parsing data for kavieng.json | 221 of 534
# loading and parsing data for kearney.json | 222 of 534
# loading and parsing data for kenai.json | 223 of 534
# loading and parsing data for kerema.json | 224 of 534
# loading and parsing data for ketchikan.json | 225 of 534
# loading and parsing data for khatanga.json | 226 of 534
# loading and parsing data for kiama.json | 227 of 534
# loading and parsing data for kieta.json | 228 of 534
# loading and parsing data for kimbe.json | 229 of 534
# loading and parsing data for kintampo.json | 230 of 534
# loading and parsing data for kirakira.json | 231 of 534
# loading and parsing data for kiruna.json | 232 of 534
# loading and parsing data for klyuchi.json | 233 of 534
# loading and parsing data for kodiak.json | 234 of 534
# loading and parsing data for kokkola.json | 235 of 534
# loading and parsing data for komsomolskiy.json | 236 of 534
# loading and parsing data for kondinskoye.json | 237 of 534
# loading and parsing data for korfovskiy.json | 238 of 534
# loading and parsing data for korhogo.json | 239 of 534
# loading and parsing data for koslan.json | 240 of 534
# loading and parsing data for kouroussa.json | 241 of 534
# loading and parsing data for koutiala.json | 242 of 534
# loading and parsing data for kralendijk.json | 243 of 534
# loading and parsing data for kruisfontein.json | 244 of 534
# loading and parsing data for kucevo.json | 245 of 534
# loading and parsing data for kuching.json | 246 of 534
# loading and parsing data for kununurra.json | 247 of 534
# loading and parsing data for kwinana.json | 248 of 534
# loading and parsing data for lagoa.json | 249 of 534
# loading and parsing data for laguna.json | 250 of 534
# loading and parsing data for lambarene.json | 251 of 534
# loading and parsing data for laredo.json | 252 of 534
# loading and parsing data for lashio.json | 253 of 534
# loading and parsing data for lata.json | 254 of 534
# loading and parsing data for lavrentiya.json | 255 of 534
# loading and parsing data for lebu.json | 256 of 534
# loading and parsing data for leningradskiy.json | 257 of 534
# loading and parsing data for leninskoye.json | 258 of 534
# loading and parsing data for lewistown.json | 259 of 534
# loading and parsing data for lima.json | 260 of 534
# loading and parsing data for lingao.json | 261 of 534
# loading and parsing data for ljungby.json | 262 of 534
# loading and parsing data for lloydminster.json | 263 of 534
# loading and parsing data for lompoc.json | 264 of 534
# loading and parsing data for longyearbyen.json | 265 of 534
# loading and parsing data for lorengau.json | 266 of 534
# loading and parsing data for los llanos de aridane.json | 267 of 534
# loading and parsing data for luanda.json | 268 of 534
# loading and parsing data for luang prabang.json | 269 of 534
# loading and parsing data for lucea.json | 270 of 534
# loading and parsing data for luderitz.json | 271 of 534
# loading and parsing data for maceio.json | 272 of 534
# loading and parsing data for mahebourg.json | 273 of 534
# loading and parsing data for mahon.json | 274 of 534
# loading and parsing data for maine-soroa.json | 275 of 534
# loading and parsing data for makakilo city.json | 276 of 534
# loading and parsing data for makanya.json | 277 of 534
# loading and parsing data for maksi.json | 278 of 534
# loading and parsing data for makushino.json | 279 of 534
# loading and parsing data for mamallapuram.json | 280 of 534
# loading and parsing data for mandali.json | 281 of 534
# loading and parsing data for maniitsoq.json | 282 of 534
# loading and parsing data for manokwari.json | 283 of 534
# loading and parsing data for manta.json | 284 of 534
# loading and parsing data for maputo.json | 285 of 534
# loading and parsing data for mar del plata.json | 286 of 534
# loading and parsing data for margate.json | 287 of 534
# loading and parsing data for marshfield.json | 288 of 534
# loading and parsing data for matara.json | 289 of 534
# loading and parsing data for mataura.json | 290 of 534
# loading and parsing data for matay.json | 291 of 534
# loading and parsing data for mayo.json | 292 of 534
# loading and parsing data for mayumba.json | 293 of 534
# loading and parsing data for mazamari.json | 294 of 534
# loading and parsing data for mehamn.json | 295 of 534
# loading and parsing data for melville.json | 296 of 534
# loading and parsing data for mende.json | 297 of 534
# loading and parsing data for meulaboh.json | 298 of 534
# loading and parsing data for mezen.json | 299 of 534
# loading and parsing data for mezhova.json | 300 of 534
# loading and parsing data for middelburg.json | 301 of 534
# loading and parsing data for midland.json | 302 of 534
# loading and parsing data for minab.json | 303 of 534
# loading and parsing data for mitu.json | 304 of 534
# loading and parsing data for mogadishu.json | 305 of 534
# loading and parsing data for monroe.json | 306 of 534
# loading and parsing data for monrovia.json | 307 of 534
# loading and parsing data for mortka.json | 308 of 534
# loading and parsing data for mount gambier.json | 309 of 534
# loading and parsing data for mount isa.json | 310 of 534
# loading and parsing data for moyobamba.json | 311 of 534
# loading and parsing data for muisne.json | 312 of 534
# loading and parsing data for mulege.json | 313 of 534
# loading and parsing data for muros.json | 314 of 534
# loading and parsing data for mwingi.json | 315 of 534
# loading and parsing data for namatanai.json | 316 of 534
# loading and parsing data for namibe.json | 317 of 534
# loading and parsing data for nanakuli.json | 318 of 534
# loading and parsing data for nanortalik.json | 319 of 534
# loading and parsing data for nara.json | 320 of 534
# loading and parsing data for narrabri.json | 321 of 534
# loading and parsing data for natchitoches.json | 322 of 534
# loading and parsing data for naze.json | 323 of 534
# loading and parsing data for neka.json | 324 of 534
# loading and parsing data for nelson bay.json | 325 of 534
# loading and parsing data for nemuro.json | 326 of 534
# loading and parsing data for new norfolk.json | 327 of 534
# loading and parsing data for nikolskoye.json | 328 of 534
# loading and parsing data for norman wells.json | 329 of 534
# loading and parsing data for ocos.json | 330 of 534
# loading and parsing data for okhotsk.json | 331 of 534
# loading and parsing data for oktyabrskoye.json | 332 of 534
# loading and parsing data for onega.json | 333 of 534
# loading and parsing data for opuwo.json | 334 of 534
# loading and parsing data for oranjemund.json | 335 of 534
# loading and parsing data for orikhiv.json | 336 of 534
# loading and parsing data for orikhove.json | 337 of 534
# loading and parsing data for osakarovka.json | 338 of 534
# loading and parsing data for osoyoos.json | 339 of 534
# loading and parsing data for ostrovnoy.json | 340 of 534
# loading and parsing data for paamiut.json | 341 of 534
# loading and parsing data for pacatuba.json | 342 of 534
# loading and parsing data for padang.json | 343 of 534
# loading and parsing data for paita.json | 344 of 534
# loading and parsing data for palmer.json | 345 of 534
# loading and parsing data for pamanukan.json | 346 of 534
# loading and parsing data for pangnirtung.json | 347 of 534
# loading and parsing data for panguna.json | 348 of 534
# loading and parsing data for patnos.json | 349 of 534
# loading and parsing data for pergamino.json | 350 of 534
# loading and parsing data for petropavlovsk-kamchatskiy.json | 351 of 534
# loading and parsing data for pevek.json | 352 of 534
# loading and parsing data for phuket.json | 353 of 534
# loading and parsing data for pimentel.json | 354 of 534
# loading and parsing data for pirovskoye.json | 355 of 534
# loading and parsing data for pisco.json | 356 of 534
# loading and parsing data for pitea.json | 357 of 534
# loading and parsing data for pizarro.json | 358 of 534
# loading and parsing data for plotnikovo.json | 359 of 534
# loading and parsing data for pokhara.json | 360 of 534
# loading and parsing data for polewali.json | 361 of 534
# loading and parsing data for poli.json | 362 of 534
# loading and parsing data for poltavka.json | 363 of 534
# loading and parsing data for polyarnyy.json | 364 of 534
# loading and parsing data for ponta do sol.json | 365 of 534
# loading and parsing data for porirua.json | 366 of 534
# loading and parsing data for port alfred.json | 367 of 534
# loading and parsing data for port blair.json | 368 of 534
# loading and parsing data for port elizabeth.json | 369 of 534
# loading and parsing data for port hedland.json | 370 of 534
# loading and parsing data for port lincoln.json | 371 of 534
# loading and parsing data for port macquarie.json | 372 of 534
# loading and parsing data for porto novo.json | 373 of 534
# loading and parsing data for praia da vitoria.json | 374 of 534
# loading and parsing data for praya.json | 375 of 534
# loading and parsing data for presidencia roque saenz pena.json | 376 of 534
# loading and parsing data for provideniya.json | 377 of 534
# loading and parsing data for puente de ixtla.json | 378 of 534
# loading and parsing data for puerto ayora.json | 379 of 534
# loading and parsing data for puerto carreno.json | 380 of 534
# loading and parsing data for punta arenas.json | 381 of 534
# loading and parsing data for qaanaaq.json | 382 of 534
# loading and parsing data for qasigiannguit.json | 383 of 534
# loading and parsing data for quatre cocos.json | 384 of 534
# loading and parsing data for quzhou.json | 385 of 534
# loading and parsing data for radcliff.json | 386 of 534
# loading and parsing data for rawson.json | 387 of 534
# loading and parsing data for ribeira grande.json | 388 of 534
# loading and parsing data for richards bay.json | 389 of 534
# loading and parsing data for rikitea.json | 390 of 534
# loading and parsing data for riyadh.json | 391 of 534
# loading and parsing data for roald.json | 392 of 534
# loading and parsing data for robinson.json | 393 of 534
# loading and parsing data for rudnichnyy.json | 394 of 534
# loading and parsing data for russell.json | 395 of 534
# loading and parsing data for sabalgarh.json | 396 of 534
# loading and parsing data for sabha.json | 397 of 534
# loading and parsing data for saint george.json | 398 of 534
# loading and parsing data for saint-agapit.json | 399 of 534
# loading and parsing data for saint-augustin.json | 400 of 534
# loading and parsing data for saint-georges.json | 401 of 534
# loading and parsing data for saint-joseph.json | 402 of 534
# loading and parsing data for saint-leu.json | 403 of 534
# loading and parsing data for saint-philippe.json | 404 of 534
# loading and parsing data for saint-pierre.json | 405 of 534
# loading and parsing data for salalah.json | 406 of 534
# loading and parsing data for salamanca.json | 407 of 534
# loading and parsing data for saldanha.json | 408 of 534
# loading and parsing data for salinopolis.json | 409 of 534
# loading and parsing data for samarai.json | 410 of 534
# loading and parsing data for san carlos del zulia.json | 411 of 534
# loading and parsing data for san cristobal.json | 412 of 534
# loading and parsing data for san felipe.json | 413 of 534
# loading and parsing data for san nicolas.json | 414 of 534
# loading and parsing data for san patricio.json | 415 of 534
# loading and parsing data for san policarpo.json | 416 of 534
# loading and parsing data for san quintin.json | 417 of 534
# loading and parsing data for san vicente.json | 418 of 534
# loading and parsing data for sangueya.json | 419 of 534
# loading and parsing data for santa cruz del sur.json | 420 of 534
# loading and parsing data for santa marta.json | 421 of 534
# loading and parsing data for santiago del estero.json | 422 of 534
# loading and parsing data for santo tomas.json | 423 of 534
# loading and parsing data for sao felix do xingu.json | 424 of 534
# loading and parsing data for sao filipe.json | 425 of 534
# loading and parsing data for sao gabriel.json | 426 of 534
# loading and parsing data for sao sepe.json | 427 of 534
# loading and parsing data for sarakhs.json | 428 of 534
# loading and parsing data for saskylakh.json | 429 of 534
# loading and parsing data for sawakin.json | 430 of 534
# loading and parsing data for sergeyevka.json | 431 of 534
# loading and parsing data for serpa.json | 432 of 534
# loading and parsing data for sesheke.json | 433 of 534
# loading and parsing data for severo-kurilsk.json | 434 of 534
# loading and parsing data for seydi.json | 435 of 534
# loading and parsing data for shediac.json | 436 of 534
# loading and parsing data for shenjiamen.json | 437 of 534
# loading and parsing data for shingu.json | 438 of 534
# loading and parsing data for sinnamary.json | 439 of 534
# loading and parsing data for sistranda.json | 440 of 534
# loading and parsing data for sitka.json | 441 of 534
# loading and parsing data for sitrah.json | 442 of 534
# loading and parsing data for sokoni.json | 443 of 534
# loading and parsing data for sol-iletsk.json | 444 of 534
# loading and parsing data for sola.json | 445 of 534
# loading and parsing data for sorland.json | 446 of 534
# loading and parsing data for sortland.json | 447 of 534
# loading and parsing data for souillac.json | 448 of 534
# loading and parsing data for soyo.json | 449 of 534
# loading and parsing data for srednekolymsk.json | 450 of 534
# loading and parsing data for suntar.json | 451 of 534
# loading and parsing data for suoyarvi.json | 452 of 534
# loading and parsing data for sur.json | 453 of 534
# loading and parsing data for swan hill.json | 454 of 534
# loading and parsing data for szigetvar.json | 455 of 534
# loading and parsing data for tabora.json | 456 of 534
# loading and parsing data for talnakh.json | 457 of 534
# loading and parsing data for taltal.json | 458 of 534
# loading and parsing data for tangermunde.json | 459 of 534
# loading and parsing data for tarakan.json | 460 of 534
# loading and parsing data for tasiilaq.json | 461 of 534
# loading and parsing data for taybad.json | 462 of 534
# loading and parsing data for te anau.json | 463 of 534
# loading and parsing data for terme.json | 464 of 534
# loading and parsing data for tevaitoa.json | 465 of 534
# loading and parsing data for the valley.json | 466 of 534
# loading and parsing data for thinadhoo.json | 467 of 534
# loading and parsing data for thompson.json | 468 of 534
# loading and parsing data for tiksi.json | 469 of 534
# loading and parsing data for tocopilla.json | 470 of 534
# loading and parsing data for tommot.json | 471 of 534
# loading and parsing data for tomohon.json | 472 of 534
# loading and parsing data for toora-khem.json | 473 of 534
# loading and parsing data for torbay.json | 474 of 534
# loading and parsing data for toropets.json | 475 of 534
# loading and parsing data for touros.json | 476 of 534
# loading and parsing data for trairi.json | 477 of 534
# loading and parsing data for tselinnoye.json | 478 of 534
# loading and parsing data for tual.json | 479 of 534
# loading and parsing data for tuatapere.json | 480 of 534
# loading and parsing data for tuktoyaktuk.json | 481 of 534
# loading and parsing data for tulun.json | 482 of 534
# loading and parsing data for tura.json | 483 of 534
# loading and parsing data for turukhansk.json | 484 of 534
# loading and parsing data for udachnyy.json | 485 of 534
# loading and parsing data for udaipura.json | 486 of 534
# loading and parsing data for uglekamensk.json | 487 of 534
# loading and parsing data for uige.json | 488 of 534
# loading and parsing data for ukiah.json | 489 of 534
# loading and parsing data for ulagan.json | 490 of 534
# loading and parsing data for umba.json | 491 of 534
# loading and parsing data for upernavik.json | 492 of 534
# loading and parsing data for ushuaia.json | 493 of 534
# loading and parsing data for ust-nera.json | 494 of 534
# loading and parsing data for ust-tsilma.json | 495 of 534
# loading and parsing data for uzhur.json | 496 of 534
# loading and parsing data for vagamo.json | 497 of 534
# loading and parsing data for vaini.json | 498 of 534
# loading and parsing data for vaitape.json | 499 of 534
# loading and parsing data for vallenar.json | 500 of 534
# loading and parsing data for valley city.json | 501 of 534
# loading and parsing data for vardo.json | 502 of 534
# loading and parsing data for varkaus.json | 503 of 534
# loading and parsing data for victoria.json | 504 of 534
# loading and parsing data for vieques.json | 505 of 534
# loading and parsing data for vila velha.json | 506 of 534
# loading and parsing data for villanueva de la serena.json | 507 of 534
# loading and parsing data for voh.json | 508 of 534
# loading and parsing data for vostok.json | 509 of 534
# loading and parsing data for vysokogornyy.json | 510 of 534
# loading and parsing data for waingapu.json | 511 of 534
# loading and parsing data for waipawa.json | 512 of 534
# loading and parsing data for walvis bay.json | 513 of 534
# loading and parsing data for warangal.json | 514 of 534
# loading and parsing data for worcester.json | 515 of 534
# loading and parsing data for wote.json | 516 of 534
# loading and parsing data for xiaoweizhai.json | 517 of 534
# loading and parsing data for xuddur.json | 518 of 534
# loading and parsing data for yabelo.json | 519 of 534
# loading and parsing data for yakovlevka.json | 520 of 534
# loading and parsing data for yar-sale.json | 521 of 534
# loading and parsing data for yatou.json | 522 of 534
# loading and parsing data for yayva.json | 523 of 534
# loading and parsing data for yellowknife.json | 524 of 534
# loading and parsing data for yeppoon.json | 525 of 534
# loading and parsing data for yerbogachen.json | 526 of 534
# loading and parsing data for yuanping.json | 527 of 534
# loading and parsing data for yulara.json | 528 of 534
# loading and parsing data for yumen.json | 529 of 534
# loading and parsing data for zakamensk.json | 530 of 534
# loading and parsing data for zhezkazgan.json | 531 of 534
# loading and parsing data for zhicheng.json | 532 of 534
# loading and parsing data for zhigansk.json | 533 of 534
# loading and parsing data for zhob.json | 534 of 534
#
# ------------------------------
# Finished Loading, Parsing and extracting Data
# ------------------------------
# No errors found, task finished successfully
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citiesDF = pd.DataFrame({
                        "City": CityName,
                        "Cloudiness": Cloudiness,
                        "CountryCode": CountryCode,
                        "Date": Date,
                        "Humidity": Humidity,
                        "Lat": Lat,
                        "Lng": Lng,
                        "MaxTemp": MaxTemp,
                        "WindSpeed": WindSpeed
                        })
print(citiesDF.count())
citiesDF.head(10)
# Out:
# City           534
# Cloudiness     534
# CountryCode    534
# Date           534
# Humidity       534
# Lat            534
# Lng            534
# MaxTemp        534
# WindSpeed      534
# dtype: int64
#          City  Cloudiness CountryCode        Date  Humidity      Lat  \
# 0      Abaete          44          BR  1547175600        75 -19.1600
# 1   Abu Dhabi          20          AE  1547175600        95  24.4748
# 2  Abu Samrah           0          SY  1547175600        85  35.3029
# 3    Acapulco           0          MX  1547175600        84  16.8603
# 4       Adrar           0          DZ  1547175600        54  27.8734
# 5     Ahipara          36          NZ  1547175600        67 -35.1665
# 6       Airai          32          TL  1547175600        83  -8.9266
# 7     Aklavik          76          CA  1547175600        46  68.2183
# 8     Aksarka          32          RU  1547175600         0  66.5606
# 9      Albany          80          US  1547175600        59  42.6512
#
#         Lng  MaxTemp  WindSpeed
# 0  -45.4459    21.51       0.91
# 1   54.3706    20.04       8.36
# 2   37.1841    -2.09       2.21
# 3  -99.8769    24.17       3.16
# 4   -0.2875     3.40       1.31
# 5  173.1562    24.69       4.21
# 6  125.4092    27.41       0.81
# 7 -135.0136   -30.80       2.41
# 8   67.7975   -30.32       3.71
# 9  -73.7550    -4.62       4.36

# %%
#Exporting data as csv
try:
    citiesDF.to_csv(output_data_file)
    #os.system("rm tmp/*.json")
except:
    print("Something Went Wrong...")
    raise

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure().suptitle(' Latitude vs. Temperature Plot (10/01/2019)', fontsize=20)
plt.scatter(Lat, MaxTemp, marker="o", facecolors="red", edgecolors="black",
            s=Lat, alpha=0.75)
plt.xlabel('Latitude', fontsize=18)
plt.ylabel('Temperatura (Centrigrados)', fontsize=16)
plt.savefig('Latitude vs Temperature Plot.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\Kamino\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
#Este es el ejemplo original de la tarea, la deje tal cual para tener una referencia

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure().suptitle(' Latitude vs. Humidty Plot (10/01/2019)', fontsize=20)
plt.scatter(Lat, Humidity, marker="o", facecolors="blue", edgecolors="black",
            s=Lat, alpha=0.75)
plt.xlabel('Latitude', fontsize=18)
plt.ylabel('Humedad', fontsize=16)
plt.savefig('Latitude vs Humidty Plot.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\Kamino\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
#Este es el ejemplo original de la tarea, la deje tal cual para tener una referencia

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure().suptitle(' Latitude vs. Cloudiness Plot (10/01/2019)', fontsize=20)
plt.scatter(Lat, Cloudiness, marker="o", facecolors="green", edgecolors="black",
            s=Lat, alpha=0.75)
plt.xlabel('Latitude', fontsize=18)
plt.ylabel('Nubosidad', fontsize=16)
plt.savefig('Latitude vs Cloudiness Plot.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\Kamino\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
#Este es el ejemplo original de la tarea, la deje tal cual para tener una referencia

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure().suptitle(' Latitude vs. Wind Speed Plot (10/01/2019)', fontsize=20)
plt.scatter(Lat, WindSpeed, marker="o", facecolors="yellow", edgecolors="black",
            s=Lat, alpha=0.75)
plt.xlabel('Latitude', fontsize=18)
plt.ylabel('Nubosidad', fontsize=16)
plt.savefig('Latitude vs WindSpeed Plot.png')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\Kamino\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
#Este es el ejemplo original de la tarea, la deje tal cual para tener una referencia
